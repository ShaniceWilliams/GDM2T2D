# %% [markdown]
# # GD2T2D: EDA
#
# This notebook contains the initial exploration and preparation of the dataset.
#
# As this is a medical dataset, this data was sythensised by researchers looking to predict the risk of Type II Diabetes in women with a history of Gestational Diabetes. They

# %%
# Imports
import pandas as pd

# %%
data_path = "../data/raw/gdm_t2dm_risk_dataset.csv"

# %%
df = pd.read_csv(data_path)

# %%
df.head().T
# Out:
#                                                     0  1  2  3  4
# Older_maternal_age                                  1  0  1  0  1
# High_pre_pregnancy_BMI_or_overweight                1  0  1  1  1
# Family_history_of_diabetes                          0  0  0  0  0
# Socioeconomic factors (deprivation quintile)        2  1  3  4  5
# Presence_of_T2DM_associated_gene_variants           0  0  0  0  0
# Ethnicity                                           4  3  3  3  3
# Multiparity                                         0  0  1  1  1
# Insulin_treatment_during_pregnancy                  0  0  1  1  1
# Pregnancy_complications_hypertensive_disorders      1  0  1  1  1
# Pregnancy_complications_preterm_delivery            0  0  1  1  1
# Pregnancy_complications_PPH                         1  0  0  0  0
# Gestational_weight_gain                             1  0  1  1  1
# Abnormal_OGTT_results                               1  0  1  1  1
# Elevated_HbA1c_during_pregnancy                     0  0  1  1  1
# Large_for_gestational_age                           0  0  1  1  1
# Macrosomia_baby_birth_weight(Delivered_a_baby_g...  0  0  1  1  1
# Instrumental_delivery                               0  0  0  1  1
# Stillbirth_Miscarriage                              0  0  0  0  0
# NICU_admission                                      0  0  0  0  1
# Perinatal_outcome_28_day_mortality                  0  0  0  0  0
# Obesity_or_unhealthy_postpartum_weight_gain         1  0  1  1  1
# Physical_inactivity                                 1  0  1  1  1
# Unhealthy_diet                                      1  0  1  1  1
# Smoking                                             0  0  0  1  0
# Alcohol_intake                                      0  0  0  0  0
# Does_not_undergo_postpartum_glucose_screening       1  0  1  1  0
# Breastfeeding                                       1  1  0  1  0
# History_of_Recurrence_of_GDM                        0  0  0  0  1
# T2DM_risk                                           0  0  1  1  1

# %% [markdown]
# ## Data Preparation
# - Is there any missing data?
# - Update column names (remove spaces, lowercase, brackers)
# - Identify column data types

# %% [markdown]
# ### Missing values

# %%
df.isnull().sum()
# Out:
# Older_maternal_age                                                   0
# High_pre_pregnancy_BMI_or_overweight                                 0
# Family_history_of_diabetes                                           0
# Socioeconomic factors (deprivation quintile)                         0
# Presence_of_T2DM_associated_gene_variants                            0
# Ethnicity                                                            0
# Multiparity                                                          0
# Insulin_treatment_during_pregnancy                                   0
# Pregnancy_complications_hypertensive_disorders                       0
# Pregnancy_complications_preterm_delivery                             0
# Pregnancy_complications_PPH                                          0
# Gestational_weight_gain                                              0
# Abnormal_OGTT_results                                                0
# Elevated_HbA1c_during_pregnancy                                      0
# Large_for_gestational_age                                            0
# Macrosomia_baby_birth_weight(Delivered_a_baby_greater_than_3_5kg)    0
# Instrumental_delivery                                                0
# Stillbirth_Miscarriage                                               0
# NICU_admission                                                       0
# Perinatal_outcome_28_day_mortality                                   0
# Obesity_or_unhealthy_postpartum_weight_gain                          0
# Physical_inactivity                                                  0
# Unhealthy_diet                                                       0
# Smoking                                                              0
# Alcohol_intake                                                       0
# Does_not_undergo_postpartum_glucose_screening                        0
# Breastfeeding                                                        0
# History_of_Recurrence_of_GDM                                         0
# T2DM_risk                                                            0
# dtype: int64

# %% [markdown]
# There are no missing values natively. Also need to check if missing values were handled in the data initially and if we need to deal with that in anyway. Like were missing values just replaced with zeros or 99s.

# %%
# Update column names to be all lower case
df.columns = df.columns.str.lower().str.replace(" ", "_").str.replace("(", "").str.replace(")", "")

# %%
df.head().T
# Out:
#                                                     0  1  2  3  4
# older_maternal_age                                  1  0  1  0  1
# high_pre_pregnancy_bmi_or_overweight                1  0  1  1  1
# family_history_of_diabetes                          0  0  0  0  0
# socioeconomic_factors_deprivation_quintile          2  1  3  4  5
# presence_of_t2dm_associated_gene_variants           0  0  0  0  0
# ethnicity                                           4  3  3  3  3
# multiparity                                         0  0  1  1  1
# insulin_treatment_during_pregnancy                  0  0  1  1  1
# pregnancy_complications_hypertensive_disorders      1  0  1  1  1
# pregnancy_complications_preterm_delivery            0  0  1  1  1
# pregnancy_complications_pph                         1  0  0  0  0
# gestational_weight_gain                             1  0  1  1  1
# abnormal_ogtt_results                               1  0  1  1  1
# elevated_hba1c_during_pregnancy                     0  0  1  1  1
# large_for_gestational_age                           0  0  1  1  1
# macrosomia_baby_birth_weightdelivered_a_baby_gr...  0  0  1  1  1
# instrumental_delivery                               0  0  0  1  1
# stillbirth_miscarriage                              0  0  0  0  0
# nicu_admission                                      0  0  0  0  1
# perinatal_outcome_28_day_mortality                  0  0  0  0  0
# obesity_or_unhealthy_postpartum_weight_gain         1  0  1  1  1
# physical_inactivity                                 1  0  1  1  1
# unhealthy_diet                                      1  0  1  1  1
# smoking                                             0  0  0  1  0
# alcohol_intake                                      0  0  0  0  0
# does_not_undergo_postpartum_glucose_screening       1  0  1  1  0
# breastfeeding                                       1  1  0  1  0
# history_of_recurrence_of_gdm                        0  0  0  0  1
# t2dm_risk                                           0  0  1  1  1

# %% [markdown]
# ### Column Data Types

# %%
df.dtypes
# Out:
# older_maternal_age                                                 int64
# high_pre_pregnancy_bmi_or_overweight                               int64
# family_history_of_diabetes                                         int64
# socioeconomic_factors_deprivation_quintile                         int64
# presence_of_t2dm_associated_gene_variants                          int64
# ethnicity                                                          int64
# multiparity                                                        int64
# insulin_treatment_during_pregnancy                                 int64
# pregnancy_complications_hypertensive_disorders                     int64
# pregnancy_complications_preterm_delivery                           int64
# pregnancy_complications_pph                                        int64
# gestational_weight_gain                                            int64
# abnormal_ogtt_results                                              int64
# elevated_hba1c_during_pregnancy                                    int64
# large_for_gestational_age                                          int64
# macrosomia_baby_birth_weightdelivered_a_baby_greater_than_3_5kg    int64
# instrumental_delivery                                              int64
# stillbirth_miscarriage                                             int64
# nicu_admission                                                     int64
# perinatal_outcome_28_day_mortality                                 int64
# obesity_or_unhealthy_postpartum_weight_gain                        int64
# physical_inactivity                                                int64
# unhealthy_diet                                                     int64
# smoking                                                            int64
# alcohol_intake                                                     int64
# does_not_undergo_postpartum_glucose_screening                      int64
# breastfeeding                                                      int64
# history_of_recurrence_of_gdm                                       int64
# t2dm_risk                                                          int64
# dtype: object

# %%
df.describe().T
# Out:
#                                                      count      mean  \
# older_maternal_age                                  6000.0  0.418333
# high_pre_pregnancy_bmi_or_overweight                6000.0  0.475167
# family_history_of_diabetes                          6000.0  0.050333
# socioeconomic_factors_deprivation_quintile          6000.0  3.027500
# presence_of_t2dm_associated_gene_variants           6000.0  0.003000
# ethnicity                                           6000.0  2.247167
# multiparity                                         6000.0  0.596000
# insulin_treatment_during_pregnancy                  6000.0  0.314333
# pregnancy_complications_hypertensive_disorders      6000.0  0.405333
# pregnancy_complications_preterm_delivery            6000.0  0.273833
# pregnancy_complications_pph                         6000.0  0.092000
# gestational_weight_gain                             6000.0  0.578333
# abnormal_ogtt_results                               6000.0  0.528667
# elevated_hba1c_during_pregnancy                     6000.0  0.383167
# large_for_gestational_age                           6000.0  0.386000
# macrosomia_baby_birth_weightdelivered_a_baby_gr...  6000.0  0.386333
# instrumental_delivery                               6000.0  0.224333
# stillbirth_miscarriage                              6000.0  0.000000
# nicu_admission                                      6000.0  0.072667
# perinatal_outcome_28_day_mortality                  6000.0  0.000000
# obesity_or_unhealthy_postpartum_weight_gain         6000.0  0.589333
# physical_inactivity                                 6000.0  0.620833
# unhealthy_diet                                      6000.0  0.391667
# smoking                                             6000.0  0.153000
# alcohol_intake                                      6000.0  0.290167
# does_not_undergo_postpartum_glucose_screening       6000.0  0.410167
# breastfeeding                                       6000.0  0.651833
# history_of_recurrence_of_gdm                        6000.0  0.158000
# t2dm_risk                                           6000.0  0.250000
#
#                                                          std  min  25%  50%  \
# older_maternal_age                                  0.493327  0.0  0.0  0.0
# high_pre_pregnancy_bmi_or_overweight                0.499425  0.0  0.0  0.0
# family_history_of_diabetes                          0.218650  0.0  0.0  0.0
# socioeconomic_factors_deprivation_quintile          1.407743  1.0  2.0  3.0
# presence_of_t2dm_associated_gene_variants           0.054695  0.0  0.0  0.0
# ethnicity                                           1.351436  0.0  1.0  3.0
# multiparity                                         0.490738  0.0  0.0  1.0
# insulin_treatment_during_pregnancy                  0.464289  0.0  0.0  0.0
# pregnancy_complications_hypertensive_disorders      0.490997  0.0  0.0  0.0
# pregnancy_complications_preterm_delivery            0.445962  0.0  0.0  0.0
# pregnancy_complications_pph                         0.289050  0.0  0.0  0.0
# gestational_weight_gain                             0.493867  0.0  0.0  1.0
# abnormal_ogtt_results                               0.499219  0.0  0.0  1.0
# elevated_hba1c_during_pregnancy                     0.486199  0.0  0.0  0.0
# large_for_gestational_age                           0.486871  0.0  0.0  0.0
# macrosomia_baby_birth_weightdelivered_a_baby_gr...  0.486949  0.0  0.0  0.0
# instrumental_delivery                               0.417177  0.0  0.0  0.0
# stillbirth_miscarriage                              0.000000  0.0  0.0  0.0
# nicu_admission                                      0.259610  0.0  0.0  0.0
# perinatal_outcome_28_day_mortality                  0.000000  0.0  0.0  0.0
# obesity_or_unhealthy_postpartum_weight_gain         0.491996  0.0  0.0  1.0
# physical_inactivity                                 0.485220  0.0  0.0  1.0
# unhealthy_diet                                      0.488164  0.0  0.0  0.0
# smoking                                             0.360018  0.0  0.0  0.0
# alcohol_intake                                      0.453877  0.0  0.0  0.0
# does_not_undergo_postpartum_glucose_screening       0.491905  0.0  0.0  0.0
# breastfeeding                                       0.476429  0.0  0.0  1.0
# history_of_recurrence_of_gdm                        0.364771  0.0  0.0  0.0
# t2dm_risk                                           0.433049  0.0  0.0  0.0
#
#                                                      75%  max
# older_maternal_age                                  1.00  1.0
# high_pre_pregnancy_bmi_or_overweight                1.00  1.0
# family_history_of_diabetes                          0.00  1.0
# socioeconomic_factors_deprivation_quintile          4.00  5.0
# presence_of_t2dm_associated_gene_variants           0.00  1.0
# ethnicity                                           3.00  4.0
# multiparity                                         1.00  1.0
# insulin_treatment_during_pregnancy                  1.00  1.0
# pregnancy_complications_hypertensive_disorders      1.00  1.0
# pregnancy_complications_preterm_delivery            1.00  1.0
# pregnancy_complications_pph                         0.00  1.0
# gestational_weight_gain                             1.00  1.0
# abnormal_ogtt_results                               1.00  1.0
# elevated_hba1c_during_pregnancy                     1.00  1.0
# large_for_gestational_age                           1.00  1.0
# macrosomia_baby_birth_weightdelivered_a_baby_gr...  1.00  1.0
# instrumental_delivery                               0.00  1.0
# stillbirth_miscarriage                              0.00  0.0
# nicu_admission                                      0.00  1.0
# perinatal_outcome_28_day_mortality                  0.00  0.0
# obesity_or_unhealthy_postpartum_weight_gain         1.00  1.0
# physical_inactivity                                 1.00  1.0
# unhealthy_diet                                      1.00  1.0
# smoking                                             0.00  1.0
# alcohol_intake                                      1.00  1.0
# does_not_undergo_postpartum_glucose_screening       1.00  1.0
# breastfeeding                                       1.00  1.0
# history_of_recurrence_of_gdm                        0.00  1.0
# t2dm_risk                                           0.25  1.0

# %%
df.nunique()
# Out:
# older_maternal_age                                                 2
# high_pre_pregnancy_bmi_or_overweight                               2
# family_history_of_diabetes                                         2
# socioeconomic_factors_deprivation_quintile                         5
# presence_of_t2dm_associated_gene_variants                          2
# ethnicity                                                          5
# multiparity                                                        2
# insulin_treatment_during_pregnancy                                 2
# pregnancy_complications_hypertensive_disorders                     2
# pregnancy_complications_preterm_delivery                           2
# pregnancy_complications_pph                                        2
# gestational_weight_gain                                            2
# abnormal_ogtt_results                                              2
# elevated_hba1c_during_pregnancy                                    2
# large_for_gestational_age                                          2
# macrosomia_baby_birth_weightdelivered_a_baby_greater_than_3_5kg    2
# instrumental_delivery                                              2
# stillbirth_miscarriage                                             1
# nicu_admission                                                     2
# perinatal_outcome_28_day_mortality                                 1
# obesity_or_unhealthy_postpartum_weight_gain                        2
# physical_inactivity                                                2
# unhealthy_diet                                                     2
# smoking                                                            2
# alcohol_intake                                                     2
# does_not_undergo_postpartum_glucose_screening                      2
# breastfeeding                                                      2
# history_of_recurrence_of_gdm                                       2
# t2dm_risk                                                          2
# dtype: int64

# %% [markdown]
# There are 2 features that have only one response type `stillbirth_miscarriage` and `perinatal_outcome_28_day_mortality`. Should these features be dropped if this is the case? What value would they add except noise?
#
# There are also just 2 columns that have more that 2 response options: `socioeconomic_factors_deprivation_quintile` and `ethnicity`. How will we need to deal with these when it comes to encoding?

# %% [markdown]
# ## Exploratory Data Analysis
#
# In this section the following topics will be explored:
# - Feature Distribution
# - Class Distribution

# %% [markdown]
# ## Class Variable Distribution

# %%
df.t2dm_risk.value_counts()
# Out:
# t2dm_risk
# 0    4500
# 1    1500
# Name: count, dtype: int64

# %%
df.t2dm_risk.value_counts(normalize=True)
# Out:
# t2dm_risk
# 0    0.75
# 1    0.25
# Name: proportion, dtype: float64

# %% [markdown]
# ### Feature distribution

# %% [markdown]
# ### Feature Importance

# %%
from sklearn.metrics import mutual_info_score

# %%
mutual_info_score(df.older_maternal_age, df.t2dm_risk)
# Out:
# 0.04536418164288597

# %%
feature_names = list(df.columns)

# %%
feature_names = feature_names[:-1]

# %%
feature_names
# Out:
# ['older_maternal_age',
#  'high_pre_pregnancy_bmi_or_overweight',
#  'family_history_of_diabetes',
#  'socioeconomic_factors_deprivation_quintile',
#  'presence_of_t2dm_associated_gene_variants',
#  'ethnicity',
#  'multiparity',
#  'insulin_treatment_during_pregnancy',
#  'pregnancy_complications_hypertensive_disorders',
#  'pregnancy_complications_preterm_delivery',
#  'pregnancy_complications_pph',
#  'gestational_weight_gain',
#  'abnormal_ogtt_results',
#  'elevated_hba1c_during_pregnancy',
#  'large_for_gestational_age',
#  'macrosomia_baby_birth_weightdelivered_a_baby_greater_than_3_5kg',
#  'instrumental_delivery',
#  'stillbirth_miscarriage',
#  'nicu_admission',
#  'perinatal_outcome_28_day_mortality',
#  'obesity_or_unhealthy_postpartum_weight_gain',
#  'physical_inactivity',
#  'unhealthy_diet',
#  'smoking',
#  'alcohol_intake',
#  'does_not_undergo_postpartum_glucose_screening',
#  'breastfeeding',
#  'history_of_recurrence_of_gdm']

# %%
for category in feature_names:
    mi_score = mutual_info_score(df[category], df.t2dm_risk)
    print(f"{category.capitalize()} mutual information score: {mi_score:.3f}")
    print()
# Out:
# Older_maternal_age mutual information score: 0.045
#
# High_pre_pregnancy_bmi_or_overweight mutual information score: 0.122
#
# Family_history_of_diabetes mutual information score: 0.011
#
# Socioeconomic_factors_deprivation_quintile mutual information score: 0.000
#
# Presence_of_t2dm_associated_gene_variants mutual information score: 0.001
#
# Ethnicity mutual information score: 0.004
#
# Multiparity mutual information score: 0.004
#
# Insulin_treatment_during_pregnancy mutual information score: 0.221
#
# Pregnancy_complications_hypertensive_disorders mutual information score: 0.153
#
# Pregnancy_complications_preterm_delivery mutual information score: 0.126
#
# Pregnancy_complications_pph mutual information score: 0.019
#
# Gestational_weight_gain mutual information score: 0.126
#
# Abnormal_ogtt_results mutual information score: 0.141
#
# Elevated_hba1c_during_pregnancy mutual information score: 0.188
#
# Large_for_gestational_age mutual information score: 0.184
#
# Macrosomia_baby_birth_weightdelivered_a_baby_greater_than_3_5kg mutual information score: 0.183
#
# Instrumental_delivery mutual information score: 0.102
#
# Stillbirth_miscarriage mutual information score: 0.000
#
# Nicu_admission mutual information score: 0.036
#
# Perinatal_outcome_28_day_mortality mutual information score: 0.000
#
# Obesity_or_unhealthy_postpartum_weight_gain mutual information score: 0.135
#
# Physical_inactivity mutual information score: 0.131
#
# Unhealthy_diet mutual information score: 0.076
#
# Smoking mutual information score: 0.001
#
# Alcohol_intake mutual information score: 0.000
#
# Does_not_undergo_postpartum_glucose_screening mutual information score: 0.011
#
# Breastfeeding mutual information score: 0.004
#
# History_of_recurrence_of_gdm mutual information score: 0.143

# %%
def mutual_info_risk_score(series: pd.Series):
    return mutual_info_score(series, df.t2dm_risk)

# %%
df[feature_names].apply(mutual_info_risk_score).sort_values(ascending=False)
# Out:
# insulin_treatment_during_pregnancy                                 0.221328
# elevated_hba1c_during_pregnancy                                    0.187652
# large_for_gestational_age                                          0.183679
# macrosomia_baby_birth_weightdelivered_a_baby_greater_than_3_5kg    0.183410
# pregnancy_complications_hypertensive_disorders                     0.153425
# history_of_recurrence_of_gdm                                       0.142614
# abnormal_ogtt_results                                              0.141482
# obesity_or_unhealthy_postpartum_weight_gain                        0.134568
# physical_inactivity                                                0.130574
# gestational_weight_gain                                            0.126000
# pregnancy_complications_preterm_delivery                           0.125727
# high_pre_pregnancy_bmi_or_overweight                               0.121972
# instrumental_delivery                                              0.101833
# unhealthy_diet                                                     0.076227
# older_maternal_age                                                 0.045364
# nicu_admission                                                     0.035507
# pregnancy_complications_pph                                        0.018764
# does_not_undergo_postpartum_glucose_screening                      0.011008
# family_history_of_diabetes                                         0.010883
# breastfeeding                                                      0.004146
# ethnicity                                                          0.004041
# multiparity                                                        0.003715
# presence_of_t2dm_associated_gene_variants                          0.001155
# smoking                                                            0.001145
# socioeconomic_factors_deprivation_quintile                         0.000477
# alcohol_intake                                                     0.000063
# perinatal_outcome_28_day_mortality                                 0.000000
# stillbirth_miscarriage                                             0.000000
# dtype: float64
